# %% [markdown]
# # **GPT Settings**

# %%
# !pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /usr/local/lib/python3.12/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from openai==0.28) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai==0.28) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from openai==0.28) (3.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->openai==0.28) (2025.11.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->openai==0.28) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->openai==0.28) (4.15.0)

# %%
import openai
import os

# %% [markdown]
# # **Extract Handshake Output**

# %%
with open('/content/handshake_hex.txt', 'r') as f:  # Adjust path if needed
    hex_dump = f.read()

# %% [markdown]
# **Producing clean hex:**

# %%
import re
# Extract hex bytes using regex
hex_lines = []
for line in hex_dump.strip().split('\n'):
    # Extract only valid 2-digit hex groups
    hex_bytes = re.findall(r'\b[0-9a-fA-F]{2}\b', line)
    if hex_bytes:
        hex_lines.append(' '.join(hex_bytes))

# Join all hex lines into one full hex stream
clean_hex_output = '\n'.join(hex_lines)
print(clean_hex_output)
# Out:
# 02 00 00 00 45 00 00 34 6d 36 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3b 30 39 38 25 3e 79
# 00 00 00 00 80 02 ff ff 05 d7 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 37 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3b 57 dc 1f 22 09
# 38 25 3e 7a 80 12 ff ff 8e c7 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 38 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3b 30 39 38 25 3e 7a
# 57 dc 1f 23 50 10 00 ff c8 bf 00 00
# 02 00 00 00 45 00 00 35 6d 39 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3b 30 39 38 25 3e 7a
# 57 dc 1f 23 50 18 00 ff 58 6a 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 3a 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3b 57 dc 1f 23 09
# 38 25 3e 87 50 10 00 ff c8 b2 00 00
# 02 00 00 00 45 00 00 35 6d 3b 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3b 57 dc 1f 23 09
# 38 25 3e 87 50 18 00 ff 68 65 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 3c 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3b 30 39 38 25 3e 87
# 57 dc 1f 30 50 10 00 ff c8 a5 00 00
# 02 00 00 00 45 00 00 28 6d 3d 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3b 57 dc 1f 30 09
# 38 25 3e 87 50 11 00 ff c8 a4 00 00
# 02 00 00 00 45 00 00 28 6d 3e 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3b 30 39 38 25 3e 87
# 57 dc 1f 31 50 10 00 ff c8 a4 00 00
# 02 00 00 00 45 00 00 28 6d 3f 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3b 30 39 38 25 3e 87
# 57 dc 1f 31 50 11 00 ff c8 a3 00 00
# 02 00 00 00 45 00 00 28 6d 40 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3b 57 dc 1f 31 09
# 38 25 3e 88 50 10 00 ff c8 a3 00 00
# 02 00 00 00 45 00 00 34 6d 41 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3c 30 39 f6 62 ef 56 09
# 00 00 00 00 80 02 ff ff 96 ba 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 42 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3c 43 6e a0 90 09
# f6 62 ef 57 80 12 ff ff b2 aa 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 43 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3c 30 39 f6 62 ef 57 09
# 43 6e a0 91 50 10 00 ff ec a2 00 00
# 02 00 00 00 45 00 00 35 6d 44 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3c 30 39 f6 62 ef 57 09
# 43 6e a0 91 50 18 00 ff 7c 4d 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 45 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3c 43 6e a0 91 09
# f6 62 ef 64 50 10 00 ff ec 95 00 00
# 02 00 00 00 45 00 00 35 6d 46 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3c 43 6e a0 91 09
# f6 62 ef 64 50 18 00 ff 8c 48 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 47 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3c 30 39 f6 62 ef 64 09
# 43 6e a0 9e 50 10 00 ff ec 88 00 00
# 02 00 00 00 45 00 00 28 6d 48 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3c 43 6e a0 9e 09
# f6 62 ef 64 50 11 00 ff ec 87 00 00
# 02 00 00 00 45 00 00 28 6d 49 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3c 30 39 f6 62 ef 64 09
# 43 6e a0 9f 50 10 00 ff ec 87 00 00
# 02 00 00 00 45 00 00 28 6d 4a 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3c 30 39 f6 62 ef 64 09
# 43 6e a0 9f 50 11 00 ff ec 86 00 00
# 02 00 00 00 45 00 00 28 6d 4b 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3c 43 6e a0 9f 09
# f6 62 ef 65 50 10 00 ff ec 86 00 00
# 02 00 00 00 45 00 00 34 6d 4c 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3d 30 39 cd 2e c1 97 09
# 00 00 00 00 80 02 ff ff ed ac 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 4d 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3d 09 93 6f 1c 09
# cd 2e c1 98 80 12 ff ff 74 ec 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 4e 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3d 30 39 cd 2e c1 98 09
# 09 93 6f 1d 50 10 00 ff ae e4 00 00
# 02 00 00 00 45 00 00 35 6d 4f 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3d 30 39 cd 2e c1 98 09
# 09 93 6f 1d 50 18 00 ff 3e 8f 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 50 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3d 09 93 6f 1d 09
# cd 2e c1 a5 50 10 00 ff ae d7 00 00
# 02 00 00 00 45 00 00 35 6d 51 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3d 09 93 6f 1d 09
# cd 2e c1 a5 50 18 00 ff 4e 8a 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 52 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3d 30 39 cd 2e c1 a5 09
# 09 93 6f 2a 50 10 00 ff ae ca 00 00
# 02 00 00 00 45 00 00 28 6d 53 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3d 09 93 6f 2a 09
# cd 2e c1 a5 50 11 00 ff ae c9 00 00
# 02 00 00 00 45 00 00 28 6d 54 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3d 30 39 cd 2e c1 a5 09
# 09 93 6f 2b 50 10 00 ff ae c9 00 00
# 02 00 00 00 45 00 00 28 6d 55 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3d 30 39 cd 2e c1 a5 09
# 09 93 6f 2b 50 11 00 ff ae c8 00 00
# 02 00 00 00 45 00 00 28 6d 56 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3d 09 93 6f 2b 09
# cd 2e c1 a6 50 10 00 ff ae c8 00 00
# 02 00 00 00 45 00 00 34 6d 57 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3e 30 39 48 d3 c4 d3
# 00 00 00 00 80 02 ff ff 6e cb 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 58 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3e 45 ac 5f 99 09
# 48 d3 c4 d4 80 12 ff ff c9 74 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 59 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3e 30 39 48 d3 c4 d4
# 45 ac 5f 9a 50 10 00 ff 03 6d 00 00
# 02 00 00 00 45 00 00 35 6d 5a 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3e 30 39 48 d3 c4 d4
# 45 ac 5f 9a 50 18 00 ff 93 17 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 5b 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3e 45 ac 5f 9a 09
# 48 d3 c4 e1 50 10 00 ff 03 60 00 00
# 02 00 00 00 45 00 00 35 6d 5c 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3e 45 ac 5f 9a 09
# 48 d3 c4 e1 50 18 00 ff a3 12 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 5d 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3e 30 39 48 d3 c4 e1
# 45 ac 5f a7 50 10 00 ff 03 53 00 00
# 02 00 00 00 45 00 00 28 6d 5e 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3e 45 ac 5f a7 09
# 48 d3 c4 e1 50 11 00 ff 03 52 00 00
# 02 00 00 00 45 00 00 28 6d 5f 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3e 30 39 48 d3 c4 e1
# 45 ac 5f a8 50 10 00 ff 03 52 00 00
# 02 00 00 00 45 00 00 28 6d 60 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3e 30 39 48 d3 c4 e1
# 45 ac 5f a8 50 11 00 ff 03 51 00 00
# 02 00 00 00 45 00 00 28 6d 61 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3e 45 ac 5f a8 09
# 48 d3 c4 e2 50 10 00 ff 03 51 00 00
# 02 00 00 00 45 00 00 34 6d 62 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3f 30 39 6d 9c be a8
# 00 00 00 00 80 02 ff ff 50 2c 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 63 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3f 87 7a 63 d9 09
# 6d 9c be a9 80 12 ff ff 64 c7 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 64 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3f 30 39 6d 9c be a9
# 87 7a 63 da 50 10 00 ff 9e bf 00 00
# 02 00 00 00 45 00 00 35 6d 65 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3f 30 39 6d 9c be a9
# 87 7a 63 da 50 18 00 ff 2e 6a 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 66 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3f 87 7a 63 da 09
# 6d 9c be b6 50 10 00 ff 9e b2 00 00
# 02 00 00 00 45 00 00 35 6d 67 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3f 87 7a 63 da 09
# 6d 9c be b6 50 18 00 ff 3e 65 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 68 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3f 30 39 6d 9c be b6
# 87 7a 63 e7 50 10 00 ff 9e a5 00 00
# 02 00 00 00 45 00 00 28 6d 69 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3f 30 39 6d 9c be b6
# 87 7a 63 e7 50 11 00 ff 9e a4 00 00
# 02 00 00 00 45 00 00 28 6d 6a 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3f 87 7a 63 e7 09
# 6d 9c be b6 50 11 00 ff 9e a4 00 00
# 02 00 00 00 45 00 00 28 6d 6b 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3f 87 7a 63 e8 09
# 6d 9c be b7 50 10 00 ff 9e a3 00 00
# 02 00 00 00 45 00 00 34 6d 6c 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 40 30 39 ca 56 39 41 09
# 00 00 00 00 80 02 ff ff 78 d8 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 6d 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 40 da 8f a2 3a 09
# ca 56 39 42 80 12 ff ff fb fc 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 6e 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 40 30 39 ca 56 39 42 09
# da 8f a2 3b 50 10 00 ff 35 f5 00 00
# 02 00 00 00 45 00 00 35 6d 6f 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 40 30 39 ca 56 39 42 09
# da 8f a2 3b 50 18 00 ff c5 9f 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 70 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 40 da 8f a2 3b 09
# ca 56 39 4f 50 10 00 ff 35 e8 00 00
# 02 00 00 00 45 00 00 35 6d 71 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 40 da 8f a2 3b 09
# ca 56 39 4f 50 18 00 ff d5 9a 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 72 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 40 30 39 ca 56 39 4f 09
# da 8f a2 48 50 10 00 ff 35 db 00 00
# 02 00 00 00 45 00 00 28 6d 73 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 40 da 8f a2 48 09
# ca 56 39 4f 50 11 00 ff 35 da 00 00
# 02 00 00 00 45 00 00 28 6d 74 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 40 30 39 ca 56 39 4f 09
# da 8f a2 49 50 10 00 ff 35 da 00 00
# 02 00 00 00 45 00 00 28 6d 75 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 40 30 39 ca 56 39 4f 09
# da 8f a2 49 50 11 00 ff 35 d9 00 00
# 02 00 00 00 45 00 00 28 6d 76 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 40 da 8f a2 49 09
# ca 56 39 50 50 10 00 ff 35 d9 00 00
# 02 00 00 00 45 00 00 34 6d 77 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 41 30 39 90 6b 70 6a
# 00 00 00 00 80 02 ff ff 7b 99 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 78 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 41 ad b7 66 04 09
# 90 6b 70 6b 80 12 ff ff 67 cc 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 79 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 41 30 39 90 6b 70 6b
# ad b7 66 05 50 10 00 ff a1 c4 00 00
# 02 00 00 00 45 00 00 35 6d 7a 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 41 30 39 90 6b 70 6b
# ad b7 66 05 50 18 00 ff 31 6f 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 7b 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 41 ad b7 66 05 09
# 90 6b 70 78 50 10 00 ff a1 b7 00 00
# 02 00 00 00 45 00 00 35 6d 7c 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 41 ad b7 66 05 09
# 90 6b 70 78 50 18 00 ff 41 6a 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 7d 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 41 30 39 90 6b 70 78
# ad b7 66 12 50 10 00 ff a1 aa 00 00
# 02 00 00 00 45 00 00 28 6d 7e 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 41 ad b7 66 12 09
# 90 6b 70 78 50 11 00 ff a1 a9 00 00
# 02 00 00 00 45 00 00 28 6d 7f 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 41 30 39 90 6b 70 78
# ad b7 66 13 50 10 00 ff a1 a9 00 00
# 02 00 00 00 45 00 00 28 6d 80 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 41 30 39 90 6b 70 78
# ad b7 66 13 50 11 00 ff a1 a8 00 00
# 02 00 00 00 45 00 00 28 6d 81 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 41 ad b7 66 13 09
# 90 6b 70 79 50 10 00 ff a1 a8 00 00
# 02 00 00 00 45 00 00 34 6d 82 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 42 30 39 0a bf bc ef
# 00 00 00 00 80 02 ff ff b4 bf 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 83 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 42 90 e2 67 23 09
# 0a bf bc f0 80 12 ff ff bc a8 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 84 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 42 30 39 0a bf bc f0
# 90 e2 67 24 50 10 00 ff f6 a0 00 00
# 02 00 00 00 45 00 00 35 6d 85 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 42 30 39 0a bf bc f0
# 90 e2 67 24 50 18 00 ff 86 4b 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 86 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 42 90 e2 67 24 09
# 0a bf bc fd 50 10 00 ff f6 93 00 00
# 02 00 00 00 45 00 00 35 6d 87 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 42 90 e2 67 24 09
# 0a bf bc fd 50 18 00 ff 96 46 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 88 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 42 30 39 0a bf bc fd
# 90 e2 67 31 50 10 00 ff f6 86 00 00
# 02 00 00 00 45 00 00 28 6d 89 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 42 90 e2 67 31 09
# 0a bf bc fd 50 11 00 ff f6 85 00 00
# 02 00 00 00 45 00 00 28 6d 8a 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 42 30 39 0a bf bc fd
# 90 e2 67 32 50 10 00 ff f6 85 00 00
# 02 00 00 00 45 00 00 28 6d 8b 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 42 30 39 0a bf bc fd
# 90 e2 67 32 50 11 00 ff f6 84 00 00
# 02 00 00 00 45 00 00 28 6d 8c 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 42 90 e2 67 32 09
# 0a bf bc fe 50 10 00 ff f6 84 00 00
# 02 00 00 00 45 00 00 34 6d 8d 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 43 30 39 57 da d9 fd
# 00 00 00 00 80 02 ff ff 4a 95 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 8e 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 43 14 9b ce 95 09
# 57 da d9 fe 80 12 ff ff 67 53 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 8f 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 43 30 39 57 da d9 fe
# 14 9b ce 96 50 10 00 ff a1 4b 00 00
# 02 00 00 00 45 00 00 35 6d 90 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 43 30 39 57 da d9 fe
# 14 9b ce 96 50 18 00 ff 30 f6 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 91 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 43 14 9b ce 96 09
# 57 da da 0b 50 10 00 ff a1 3e 00 00
# 02 00 00 00 45 00 00 35 6d 92 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 43 14 9b ce 96 09
# 57 da da 0b 50 18 00 ff 40 f1 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 93 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 43 30 39 57 da da 0b
# 14 9b ce a3 50 10 00 ff a1 31 00 00
# 02 00 00 00 45 00 00 28 6d 94 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 43 14 9b ce a3 09
# 57 da da 0b 50 11 00 ff a1 30 00 00
# 02 00 00 00 45 00 00 28 6d 95 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 43 30 39 57 da da 0b
# 14 9b ce a4 50 10 00 ff a1 30 00 00
# 02 00 00 00 45 00 00 28 6d 96 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 43 30 39 57 da da 0b
# 14 9b ce a4 50 11 00 ff a1 2f 00 00
# 02 00 00 00 45 00 00 28 6d 97 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 43 14 9b ce a4 09
# 57 da da 0c 50 10 00 ff a1 2f 00 00
# 02 00 00 00 45 00 00 34 6d 98 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 44 30 39 3d 22 fe 3f
# 00 00 00 00 80 02 ff ff 41 0a 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d 99 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 44 31 b0 13 62 09 D1
# 3d 22 fe 40 80 12 ff ff fb e6 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d 9a 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 44 30 39 3d 22 fe 40
# 31 b0 13 63 50 10 00 ff 35 df 00 00
# 02 00 00 00 45 00 00 35 6d 9b 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 44 30 39 3d 22 fe 40
# 31 b0 13 63 50 18 00 ff c5 89 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d 9c 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 44 31 b0 13 63 09 D1
# 3d 22 fe 4d 50 10 00 ff 35 d2 00 00
# 02 00 00 00 45 00 00 35 6d 9d 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 44 31 b0 13 63 09 D1
# 3d 22 fe 4d 50 18 00 ff d5 84 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d 9e 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 44 30 39 3d 22 fe 4d
# 31 b0 13 70 50 10 00 ff 35 c5 00 00
# 02 00 00 00 45 00 00 28 6d 9f 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 44 31 b0 13 70 09 D1
# 3d 22 fe 4d 50 11 00 ff 35 c4 00 00
# 02 00 00 00 45 00 00 28 6d a0 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 44 30 39 3d 22 fe 4d
# 31 b0 13 71 50 10 00 ff 35 c4 00 00
# 02 00 00 00 45 00 00 28 6d a1 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 44 30 39 3d 22 fe 4d
# 31 b0 13 71 50 11 00 ff 35 c3 00 00
# 02 00 00 00 45 00 00 28 6d a2 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 44 31 b0 13 71 09 D1
# 3d 22 fe 4e 50 10 00 ff 35 c3 00 00
# 02 00 00 00 45 00 00 34 6d a3 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 45 30 39 c2 b8 d5 14
# 00 00 00 00 80 02 ff ff e4 9d 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d a4 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 45 02 b0 64 a2 09
# c2 b8 d5 15 80 12 ff ff 7d 3a 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d a5 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 45 30 39 c2 b8 d5 15
# 02 b0 64 a3 50 10 00 ff b7 32 00 00
# 02 00 00 00 45 00 00 35 6d a6 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 45 30 39 c2 b8 d5 15
# 02 b0 64 a3 50 18 00 ff 46 dd 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d a7 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 45 02 b0 64 a3 09
# c2 b8 d5 22 50 10 00 ff b7 25 00 00
# 02 00 00 00 45 00 00 35 6d a8 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 45 02 b0 64 a3 09
# c2 b8 d5 22 50 18 00 ff 56 d8 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d a9 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 45 30 39 c2 b8 d5 22
# 02 b0 64 b0 50 10 00 ff b7 18 00 00
# 02 00 00 00 45 00 00 28 6d aa 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 45 02 b0 64 b0 09
# c2 b8 d5 22 50 11 00 ff b7 17 00 00
# 02 00 00 00 45 00 00 28 6d ab 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 45 30 39 c2 b8 d5 22
# 02 b0 64 b1 50 10 00 ff b7 17 00 00
# 02 00 00 00 45 00 00 28 6d ac 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 45 30 39 c2 b8 d5 22
# 02 b0 64 b1 50 11 00 ff b7 16 00 00
# 02 00 00 00 45 00 00 28 6d ad 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 45 02 b0 64 b1 09
# c2 b8 d5 23 50 10 00 ff b7 16 00 00
# 02 00 00 00 45 00 00 34 6d ae 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 46 30 39 db 88 c7 06
# 00 00 00 00 80 02 ff ff d9 da 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d af 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 46 50 49 b0 6f 09
# db 88 c7 07 80 12 ff ff d9 10 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d b0 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 46 30 39 db 88 c7 07
# 50 49 b0 70 50 10 00 ff 13 09 00 00
# 02 00 00 00 45 00 00 35 6d b1 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 46 30 39 db 88 c7 07
# 50 49 b0 70 50 18 00 ff a2 b3 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d b2 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 46 50 49 b0 70 09
# db 88 c7 14 50 10 00 ff 12 fc 00 00
# 02 00 00 00 45 00 00 35 6d b3 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 46 50 49 b0 70 09
# db 88 c7 14 50 18 00 ff b2 ae 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d b4 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 46 30 39 db 88 c7 14
# 50 49 b0 7d 50 10 00 ff 12 ef 00 00
# 02 00 00 00 45 00 00 28 6d b5 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 46 50 49 b0 7d 09
# db 88 c7 14 50 11 00 ff 12 ee 00 00
# 02 00 00 00 45 00 00 28 6d b6 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 46 30 39 db 88 c7 14
# 50 49 b0 7e 50 10 00 ff 12 ee 00 00
# 02 00 00 00 45 00 00 28 6d b7 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 46 30 39 db 88 c7 14
# 50 49 b0 7e 50 11 00 ff 12 ed 00 00
# 02 00 00 00 45 00 00 28 6d b8 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 46 50 49 b0 7e 09
# db 88 c7 15 50 10 00 ff 12 ed 00 00
# 02 00 00 00 45 00 00 34 6d b9 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 47 30 39 c0 24 6a 04
# 00 00 00 00 80 02 ff ff 52 40 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d ba 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 47 1f e5 fd 3f 09
# c0 24 6a 05 80 12 ff ff 35 0a 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d bb 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 47 30 39 c0 24 6a 05
# 1f e5 fd 40 50 10 00 ff 6f 02 00 00
# 02 00 00 00 45 00 00 35 6d bc 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 47 30 39 c0 24 6a 05
# 1f e5 fd 40 50 18 00 ff fe ac 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d bd 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 47 1f e5 fd 40 09
# c0 24 6a 12 50 10 00 ff 6e f5 00 00
# 02 00 00 00 45 00 00 35 6d be 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 47 1f e5 fd 40 09
# c0 24 6a 12 50 18 00 ff 0e a8 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d bf 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 47 30 39 c0 24 6a 12
# 1f e5 fd 4d 50 10 00 ff 6e e8 00 00
# 02 00 00 00 45 00 00 28 6d c0 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 47 1f e5 fd 4d 09
# c0 24 6a 12 50 11 00 ff 6e e7 00 00
# 02 00 00 00 45 00 00 28 6d c1 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 47 30 39 c0 24 6a 12
# 1f e5 fd 4e 50 10 00 ff 6e e7 00 00
# 02 00 00 00 45 00 00 28 6d c2 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 47 30 39 c0 24 6a 12
# 1f e5 fd 4e 50 11 00 ff 6e e6 00 00
# 02 00 00 00 45 00 00 28 6d c3 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 47 1f e5 fd 4e 09
# c0 24 6a 13 50 10 00 ff 6e e6 00 00
# 02 00 00 00 45 00 00 34 6d c4 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 48 30 39 b1 f9 68 ff
# 00 00 00 00 80 02 ff ff 61 6f 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d c5 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 48 12 b8 2f 48 09
# b1 f9 69 00 80 12 ff ff 1f 5e 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d c6 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 48 30 39 b1 f9 69 00
# 12 b8 2f 49 50 10 00 ff 59 56 00 00
# 02 00 00 00 45 00 00 35 6d c7 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 48 30 39 b1 f9 69 00
# 12 b8 2f 49 50 18 00 ff e9 00 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d c8 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 48 12 b8 2f 49 09
# b1 f9 69 0d 50 10 00 ff 59 49 00 00
# 02 00 00 00 45 00 00 35 6d c9 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 48 12 b8 2f 49 09
# b1 f9 69 0d 50 18 00 ff f8 fb 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d ca 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 48 30 39 b1 f9 69 0d
# 12 b8 2f 56 50 10 00 ff 59 3c 00 00
# 02 00 00 00 45 00 00 28 6d cb 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 48 12 b8 2f 56 09
# b1 f9 69 0d 50 11 00 ff 59 3b 00 00
# 02 00 00 00 45 00 00 28 6d cc 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 48 30 39 b1 f9 69 0d
# 12 b8 2f 57 50 10 00 ff 59 3b 00 00
# 02 00 00 00 45 00 00 28 6d cd 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 48 30 39 b1 f9 69 0d
# 12 b8 2f 57 50 11 00 ff 59 3a 00 00
# 02 00 00 00 45 00 00 28 6d ce 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 48 12 b8 2f 57 09
# b1 f9 69 0e 50 10 00 ff 59 3a 00 00
# 02 00 00 00 45 00 00 34 6d cf 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 49 30 39 5d be 2e c1
# 00 00 00 00 80 02 ff ff ef e7 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d d0 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 49 b7 94 56 b6 09
# 5d be 2e c2 80 12 ff ff e1 8b 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d d1 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 49 30 39 5d be 2e c2
# b7 94 56 b7 50 10 00 ff 1b 84 00 00
# 02 00 00 00 45 00 00 35 6d d2 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 49 30 39 5d be 2e c2
# b7 94 56 b7 50 18 00 ff ab 2e 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d d3 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 49 b7 94 56 b7 09
# 5d be 2e cf 50 10 00 ff 1b 77 00 00
# 02 00 00 00 45 00 00 35 6d d4 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 49 b7 94 56 b7 09
# 5d be 2e cf 50 18 00 ff bb 29 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d d5 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 49 30 39 5d be 2e cf
# b7 94 56 c4 50 10 00 ff 1b 6a 00 00
# 02 00 00 00 45 00 00 28 6d d6 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 49 b7 94 56 c4 09
# 5d be 2e cf 50 11 00 ff 1b 69 00 00
# 02 00 00 00 45 00 00 28 6d d7 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 49 30 39 5d be 2e cf
# b7 94 56 c5 50 10 00 ff 1b 69 00 00
# 02 00 00 00 45 00 00 28 6d d8 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 49 30 39 5d be 2e cf
# b7 94 56 c5 50 11 00 ff 1b 68 00 00
# 02 00 00 00 45 00 00 28 6d d9 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 49 b7 94 56 c5 09
# 5d be 2e d0 50 10 00 ff 1b 68 00 00
# 02 00 00 00 45 00 00 34 6d da 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4a 30 39 ee 3f 78 55
# 00 00 00 00 80 02 ff ff 15 d1 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d db 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4a d1 3a a9 d3 09
# ee 3f 78 56 80 12 ff ff 9a b1 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d dc 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4a 30 39 ee 3f 78 56
# d1 3a a9 d4 50 10 00 ff d4 a9 00 00
# 02 00 00 00 45 00 00 35 6d dd 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4a 30 39 ee 3f 78 56
# d1 3a a9 d4 50 18 00 ff 64 54 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d de 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4a d1 3a a9 d4 09
# ee 3f 78 63 50 10 00 ff d4 9c 00 00
# 02 00 00 00 45 00 00 35 6d df 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4a d1 3a a9 d4 09
# ee 3f 78 63 50 18 00 ff 74 4f 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d e0 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4a 30 39 ee 3f 78 63
# d1 3a a9 e1 50 10 00 ff d4 8f 00 00
# 02 00 00 00 45 00 00 28 6d e1 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4a d1 3a a9 e1 09
# ee 3f 78 63 50 11 00 ff d4 8e 00 00
# 02 00 00 00 45 00 00 28 6d e2 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4a 30 39 ee 3f 78 63
# d1 3a a9 e2 50 10 00 ff d4 8e 00 00
# 02 00 00 00 45 00 00 28 6d e3 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4a 30 39 ee 3f 78 63
# d1 3a a9 e2 50 11 00 ff d4 8d 00 00
# 02 00 00 00 45 00 00 28 6d e4 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4a d1 3a a9 e2 09
# ee 3f 78 64 50 10 00 ff d4 8d 00 00
# 02 00 00 00 45 00 00 34 6d e5 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4b 30 39 68 2e a9 e7
# 00 00 00 00 80 02 ff ff 6a 4f 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d e6 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4b 8a af 10 61 09
# 68 2e a9 e8 80 12 ff ff cf 2d 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d e7 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4b 30 39 68 2e a9 e8
# 8a af 10 62 50 10 00 ff 09 26 00 00
# 02 00 00 00 45 00 00 35 6d e8 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4b 30 39 68 2e a9 e8
# 8a af 10 62 50 18 00 ff 98 d0 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d e9 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4b 8a af 10 62 09
# 68 2e a9 f5 50 10 00 ff 09 19 00 00
# 02 00 00 00 45 00 00 35 6d ea 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4b 8a af 10 62 09
# 68 2e a9 f5 50 18 00 ff a8 cb 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d eb 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4b 30 39 68 2e a9 f5
# 8a af 10 6f 50 10 00 ff 09 0c 00 00
# 02 00 00 00 45 00 00 28 6d ec 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4b 8a af 10 6f 09
# 68 2e a9 f5 50 11 00 ff 09 0b 00 00
# 02 00 00 00 45 00 00 28 6d ed 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4b 30 39 68 2e a9 f5
# 8a af 10 70 50 10 00 ff 09 0b 00 00
# 02 00 00 00 45 00 00 28 6d ee 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4b 30 39 68 2e a9 f5
# 8a af 10 70 50 11 00 ff 09 0a 00 00
# 02 00 00 00 45 00 00 28 6d ef 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4b 8a af 10 70 09
# 68 2e a9 f6 50 10 00 ff 09 0a 00 00
# 02 00 00 00 45 00 00 34 6d f0 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4c 30 39 3b 92 bd 5c
# 00 00 00 00 80 02 ff ff 83 75 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d f1 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4c 35 dc b9 51 09
# 3b 92 bd 5d 80 12 ff ff 94 36 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d f2 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4c 30 39 3b 92 bd 5d
# 35 dc b9 52 50 10 00 ff ce 2e 00 00
# 02 00 00 00 45 00 00 35 6d f3 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4c 30 39 3b 92 bd 5d
# 35 dc b9 52 50 18 00 ff 5d d9 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d f4 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4c 35 dc b9 52 09
# 3b 92 bd 6a 50 10 00 ff ce 21 00 00
# 02 00 00 00 45 00 00 35 6d f5 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4c 35 dc b9 52 09
# 3b 92 bd 6a 50 18 00 ff 6d d4 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6d f6 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4c 30 39 3b 92 bd 6a
# 35 dc b9 5f 50 10 00 ff ce 14 00 00
# 02 00 00 00 45 00 00 28 6d f7 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4c 35 dc b9 5f 09
# 3b 92 bd 6a 50 11 00 ff ce 13 00 00
# 02 00 00 00 45 00 00 28 6d f8 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4c 30 39 3b 92 bd 6a
# 35 dc b9 60 50 10 00 ff ce 13 00 00
# 02 00 00 00 45 00 00 28 6d f9 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4c 30 39 3b 92 bd 6a
# 35 dc b9 60 50 11 00 ff ce 12 00 00
# 02 00 00 00 45 00 00 28 6d fa 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4c 35 dc b9 60 09
# 3b 92 bd 6b 50 10 00 ff ce 12 00 00
# 02 00 00 00 45 00 00 34 6d fb 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4d 30 39 33 4a 97 49
# 00 00 00 00 80 02 ff ff b1 cf 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6d fc 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4d 13 a5 12 b6 09
# 33 4a 97 4a 80 12 ff ff 8b 63 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6d fd 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4d 30 39 33 4a 97 4a
# 13 a5 12 b7 50 10 00 ff c5 5b 00 00
# 02 00 00 00 45 00 00 35 6d fe 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4d 30 39 33 4a 97 4a
# 13 a5 12 b7 50 18 00 ff 55 06 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6d ff 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4d 13 a5 12 b7 09
# 33 4a 97 57 50 10 00 ff c5 4e 00 00
# 02 00 00 00 45 00 00 35 6e 00 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4d 13 a5 12 b7 09
# 33 4a 97 57 50 18 00 ff 65 01 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6e 01 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4d 30 39 33 4a 97 57
# 13 a5 12 c4 50 10 00 ff c5 41 00 00
# 02 00 00 00 45 00 00 28 6e 02 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4d 13 a5 12 c4 09
# 33 4a 97 57 50 11 00 ff c5 40 00 00
# 02 00 00 00 45 00 00 28 6e 03 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4d 30 39 33 4a 97 57
# 13 a5 12 c5 50 10 00 ff c5 40 00 00
# 02 00 00 00 45 00 00 28 6e 04 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4d 30 39 33 4a 97 57
# 13 a5 12 c5 50 11 00 ff c5 3f 00 00
# 02 00 00 00 45 00 00 28 6e 05 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4d 13 a5 12 c5 09
# 33 4a 97 58 50 10 00 ff c5 3f 00 00
# 02 00 00 00 45 00 00 34 6e 06 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4e 30 39 ab ce 1c 3b
# 00 00 00 00 80 02 ff ff b4 58 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 34 6e 07 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4e 91 98 0a f5 09
# ab ce 1c 3c 80 12 ff ff 17 ba 00 00 02 04 ff d7
# 01 03 03 08 01 01 04 02
# 02 00 00 00 45 00 00 28 6e 08 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4e 30 39 ab ce 1c 3c
# 91 98 0a f6 50 10 00 ff 51 b2 00 00
# 02 00 00 00 45 00 00 35 6e 09 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4e 30 39 ab ce 1c 3c
# 91 98 0a f6 50 18 00 ff e1 5c 00 00 48 65 6c 6c
# 6f 20 53 65 72 76 65 72 21
# 02 00 00 00 45 00 00 28 6e 0a 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4e 91 98 0a f6 09
# ab ce 1c 49 50 10 00 ff 51 a5 00 00
# 02 00 00 00 45 00 00 35 6e 0b 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4e 91 98 0a f6 09
# ab ce 1c 49 50 18 00 ff f1 57 00 00 48 65 6c 6c
# 6f 20 43 6c 69 65 6e 74 21
# 02 00 00 00 45 00 00 28 6e 0c 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4e 30 39 ab ce 1c 49
# 91 98 0b 03 50 10 00 ff 51 98 00 00
# 02 00 00 00 45 00 00 28 6e 0d 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4e 91 98 0b 03 09
# ab ce 1c 49 50 11 00 ff 51 97 00 00
# 02 00 00 00 45 00 00 28 6e 0e 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4e 30 39 ab ce 1c 49
# 91 98 0b 04 50 10 00 ff 51 97 00 00
# 02 00 00 00 45 00 00 28 6e 0f 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 4e 30 39 ab ce 1c 49
# 91 98 0b 04 50 11 00 ff 51 96 00 00
# 02 00 00 00 45 00 00 28 6e 10 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 4e 91 98 0b 04 09
# ab ce 1c 4a 50 10 00 ff 51 96 00 00
# 02 00 00 00 45 00 00 28 6e 11 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 30 39 ca 3f 87 7a 63 e7 09
# 6d 9c be b7 50 11 00 ff 9e a3 00 00
# 02 00 00 00 45 00 00 28 6e 12 40 00 80 06 00 00
# 7f 00 00 01 7f 00 00 01 ca 3f 30 39 6d 9c be b7
# 87 7a 63 e8 50 10 00 00 9f a2 00 00

# %% [markdown]
# **Getting rid of spaces from HEX data**

# %%
import pandas as pd
from google.colab import files

# 1. Paste your full hex dump inside the triple quotes
raw_hex = clean_hex_output

# 2. Clean lines and split into packets
lines = [l.strip() for l in raw_hex.splitlines() if l.strip()]

packets_with_spaces = []
current = []

for line in lines:
    # New packet starts when we see the loopback+IPv4 header pattern
    if line.startswith("02 00 00 00 45 00"):
        if current:
            packets_with_spaces.append(" ".join(current))
            current = []
    current.append(line)

# Add the last packet
if current:
    packets_with_spaces.append(" ".join(current))

# 3. Also create a version with no spaces (continuous hex string)
packets_clean = [p.replace(" ", "") for p in packets_with_spaces]

# 4. Build DataFrame
df = pd.DataFrame({
    "packet_id": range(1, len(packets_clean) + 1),
    "hex_with_spaces": packets_with_spaces,
    "hex_clean": packets_clean,
})

# 5. Save to CSV in Colab
csv_name = "tcp_packets_hex.csv"
df.to_csv(csv_name, index=False)
print(f"Saved {len(df)} packets to {csv_name}")

# 6. Offer CSV for download
files.download(csv_name)
# Out:
# Saved 221 packets to tcp_packets_hex.csv

# %% [markdown]
# **Loading Wireshark (non hex) output from CMD**

# %%
import pandas as pd

col_names = [
    "packet_id",
    "src_port",
    "dst_port",
    "seq",
    "ack",
    "tcp_hdr_len",
    "tcp_flags",
    "tcp_flag_syn",
    "tcp_flag_ack",
    "window_size",
    "checksum",
    "urgent_pointer",
    "tcp_options",
    "tcp_payload",
]

df = pd.read_csv("/content/handshake_packets.txt",
                 header=None,
                 names=col_names)

df.head()
# Out:
#    packet_id  src_port  dst_port  seq  ack  tcp_hdr_len tcp_flags  \
# 0          1     56039     12345    0    0           32    0x0002
# 1          2     12345     56039    0    1           32    0x0012
# 2          3     56039     12345    1    1           20    0x0010
# 3          4     56039     12345    1    1           20    0x0018
# 4          5     12345     56039    1   14           20    0x0010
#
#    tcp_flag_syn  tcp_flag_ack  window_size checksum  urgent_pointer  \
# 0          True         False        65535   0x953f               0
# 1          True          True        65535   0x6c5e               0
# 2         False          True          255   0xa656               0
# 3         False          True          255   0x3601               0
# 4         False          True          255   0xa649               0
#
#                 tcp_options                 tcp_payload
# 0  0204ffd70103030801010402                         NaN
# 1  0204ffd70103030801010402                         NaN
# 2                       NaN                         NaN
# 3                       NaN  48656c6c6f2053657276657221
# 4                       NaN                         NaN

# %% [markdown]
# **Decoding each TCP flag from flags column**

# %%
def decode_flags(flags_hex):
    # flags_hex like '0x0018'
    flags = int(str(flags_hex), 16)
    return pd.Series({
        "flag_FIN": bool(flags & 0x01),
        "flag_SYN": bool(flags & 0x02),
        "flag_RST": bool(flags & 0x04),
        "flag_PSH": bool(flags & 0x08),
        "flag_ACK": bool(flags & 0x10),
        "flag_URG": bool(flags & 0x20),
        "flag_ECE": bool(flags & 0x40),
        "flag_CWR": bool(flags & 0x80),
    })

df_flags = df["tcp_flags"].apply(decode_flags)
df = pd.concat([df, df_flags], axis=1)

df.head()
# Out:
#    packet_id  src_port  dst_port  seq  ack  tcp_hdr_len tcp_flags  \
# 0          1     56039     12345    0    0           32    0x0002
# 1          2     12345     56039    0    1           32    0x0012
# 2          3     56039     12345    1    1           20    0x0010
# 3          4     56039     12345    1    1           20    0x0018
# 4          5     12345     56039    1   14           20    0x0010
#
#    tcp_flag_syn  tcp_flag_ack  window_size  ...               tcp_options  \
# 0          True         False        65535  ...  0204ffd70103030801010402
# 1          True          True        65535  ...  0204ffd70103030801010402
# 2         False          True          255  ...                       NaN
# 3         False          True          255  ...                       NaN
# 4         False          True          255  ...                       NaN
#
#                   tcp_payload flag_FIN flag_SYN  flag_RST  flag_PSH  flag_ACK  \
# 0                         NaN    False     True     False     False     False
# 1                         NaN    False     True     False     False      True
# 2                         NaN    False    False     False     False      True
# 3  48656c6c6f2053657276657221    False    False     False      True      True
# 4                         NaN    False    False     False     False      True
#
#    flag_URG  flag_ECE  flag_CWR
# 0     False     False     False
# 1     False     False     False
# 2     False     False     False
# 3     False     False     False
# 4     False     False     False
#
# [5 rows x 22 columns]

# %% [markdown]
# **Categorizing PAcket Types**

# %%
def classify_pkt(row):
    syn = row["flag_SYN"]
    ack = row["flag_ACK"]
    fin = row["flag_FIN"]
    rst = row["flag_RST"]

    if syn and not ack:
        return "SYN"
    if syn and ack:
        return "SYN-ACK"
    if fin and ack:
        return "FIN-ACK"
    if fin and not ack:
        return "FIN"
    if rst:
        return "RST"
    if ack:
        return "ACK"
    return "OTHER"

df["pkt_type"] = df.apply(classify_pkt, axis=1)

df[["packet_id", "src_port", "dst_port", "tcp_flags", "pkt_type"]].head(20)
# Out:
#     packet_id  src_port  dst_port tcp_flags pkt_type
# 0           1     56039     12345    0x0002      SYN
# 1           2     12345     56039    0x0012  SYN-ACK
# 2           3     56039     12345    0x0010      ACK
# 3           4     56039     12345    0x0018      ACK
# 4           5     12345     56039    0x0010      ACK
# 5           6     12345     56039    0x0018      ACK
# 6           7     56039     12345    0x0010      ACK
# 7           8     12345     56039    0x0011  FIN-ACK
# 8           9     56039     12345    0x0010      ACK
# 9          10     56039     12345    0x0011  FIN-ACK
# 10         11     12345     56039    0x0010      ACK
# 11         12     56040     12345    0x0002      SYN
# 12         13     12345     56040    0x0012  SYN-ACK
# 13         14     56040     12345    0x0010      ACK
# 14         15     56040     12345    0x0018      ACK
# 15         16     12345     56040    0x0010      ACK
# 16         17     12345     56040    0x0018      ACK
# 17         18     56040     12345    0x0010      ACK
# 18         19     12345     56040    0x0011  FIN-ACK
# 19         20     56040     12345    0x0010      ACK

# %% [markdown]
# **Merging Two dataframes for capturing all TCP header fields with Values**

# %%
df_hex = pd.read_csv("/content/tcp_packets_hex.csv")  # packet_id, hex_with_spaces, hex_clean

df_full = df_hex.merge(df, on="packet_id", how="left")

df_full.to_csv("/content/tcp_handshake_full_tcp_headers.csv", index=False)

# %% [markdown]
# **Adding Flow Connections**

# %%
import pandas as pd

df = pd.read_csv("/content/tcp_handshake_full_tcp_headers.csv")

# loopback, so we can define a flow just by ports (smallest-biggest)
df["flow_id"] = df.apply(
    lambda r: f"{min(r.src_port, r.dst_port)}-{max(r.src_port, r.dst_port)}",
    axis=1
)
df.head()
# Out:
#    packet_id                                    hex_with_spaces  \
# 0          1  02 00 00 00 45 00 00 34 6d 36 40 00 80 06 00 0...
# 1          2  02 00 00 00 45 00 00 34 6d 37 40 00 80 06 00 0...
# 2          3  02 00 00 00 45 00 00 28 6d 38 40 00 80 06 00 0...
# 3          4  02 00 00 00 45 00 00 35 6d 39 40 00 80 06 00 0...
# 4          5  02 00 00 00 45 00 00 28 6d 3a 40 00 80 06 00 0...
#
#                                            hex_clean  src_port  dst_port  seq  \
# 0  02000000450000346d364000800600007f0000017f0000...     56039     12345    0
# 1  02000000450000346d374000800600007f0000017f0000...     12345     56039    0
# 2  02000000450000286d384000800600007f0000017f0000...     56039     12345    1
# 3  02000000450000356d394000800600007f0000017f0000...     56039     12345    1
# 4  02000000450000286d3a4000800600007f0000017f0000...     12345     56039    1
#
#    ack  tcp_hdr_len tcp_flags  tcp_flag_syn  ...  flag_FIN  flag_SYN flag_RST  \
# 0    0           32    0x0002          True  ...     False      True    False
# 1    1           32    0x0012          True  ...     False      True    False
# 2    1           20    0x0010         False  ...     False     False    False
# 3    1           20    0x0018         False  ...     False     False    False
# 4   14           20    0x0010         False  ...     False     False    False
#
#    flag_PSH flag_ACK flag_URG  flag_ECE  flag_CWR  pkt_type      flow_id
# 0     False    False    False     False     False       SYN  12345-56039
# 1     False     True    False     False     False   SYN-ACK  12345-56039
# 2     False     True    False     False     False       ACK  12345-56039
# 3      True     True    False     False     False       ACK  12345-56039
# 4     False     True    False     False     False       ACK  12345-56039
#
# [5 rows x 26 columns]

# %% [markdown]
# **Getting individual handshake outputs**

# %%
handshakes = []

for flow_id, g in df.groupby("flow_id"):
    g = g.sort_values("packet_id")

    syn = g[g["pkt_type"] == "SYN"].head(1)
    if syn.empty:
        continue

    syn_pkt = syn.iloc[0]

    syn_ack = g[(g["pkt_type"] == "SYN-ACK") &
                (g["packet_id"] > syn_pkt["packet_id"])].head(1)
    if syn_ack.empty:
        continue
    syn_ack_pkt = syn_ack.iloc[0]

    ack = g[(g["pkt_type"] == "ACK") &
            (g["packet_id"] > syn_ack_pkt["packet_id"])].head(1)
    if ack.empty:
        continue
    ack_pkt = ack.iloc[0]

    handshakes.append({
        "flow_id": flow_id,
        "syn_id": int(syn_pkt["packet_id"]),
        "syn_ack_id": int(syn_ack_pkt["packet_id"]),
        "ack_id": int(ack_pkt["packet_id"]),
    })

df_hs = pd.DataFrame(handshakes)
df_hs.head()
# Out:
#        flow_id  syn_id  syn_ack_id  ack_id
# 0  12345-56039       1           2       3
# 1  12345-56040      12          13      14
# 2  12345-56041      23          24      25
# 3  12345-56042      33          34      35
# 4  12345-56043      44          45      46

# %%
import pandas as pd

# All packets with headers + pkt_type + hex
df = pd.read_csv("/content/tcp_handshake_full_tcp_headers.csv")

# The handshake summary you just printed
df_hs = pd.DataFrame(handshakes)
  # or re-create from earlier code if needed
print(df_hs.head())
# Out:
#        flow_id  syn_id  syn_ack_id  ack_id
# 0  12345-56039       1           2       3
# 1  12345-56040      12          13      14
# 2  12345-56041      23          24      25
# 3  12345-56042      33          34      35
# 4  12345-56043      44          45      46

# %% [markdown]
# #  **1. Ground Truth**

# %%
# We'll grab only the fields we need for now
cols_keep = [
    "packet_id",
    "hex_clean",
    "pkt_type",
    "seq",
    "ack",
    "window_size",
    "tcp_flags",
]

df_small = df[cols_keep].set_index("packet_id")

handshake_rows = []

for _, row in df_hs.iterrows():
    syn     = df_small.loc[row["syn_id"]]
    synack  = df_small.loc[row["syn_ack_id"]]
    ackpkt  = df_small.loc[row["ack_id"]]

    handshake_rows.append({
        "flow_id":   row["flow_id"],

        "syn_id":    int(row["syn_id"]),
        "syn_type":  syn["pkt_type"],
        "syn_seq":   syn["seq"],
        "syn_ack":   syn["ack"],
        "syn_wss":   syn["window_size"],
        "syn_flags": syn["tcp_flags"],
        "syn_hex":   syn["hex_clean"],

        "synack_id":    int(row["syn_ack_id"]),
        "synack_type":  synack["pkt_type"],
        "synack_seq":   synack["seq"],
        "synack_ack":   synack["ack"],
        "synack_wss":   synack["window_size"],
        "synack_flags": synack["tcp_flags"],
        "synack_hex":   synack["hex_clean"],

        "ack_id":    int(row["ack_id"]),
        "ack_type":  ackpkt["pkt_type"],
        "ack_seq":   ackpkt["seq"],
        "ack_ack":   ackpkt["ack"],
        "ack_wss":   ackpkt["window_size"],
        "ack_flags": ackpkt["tcp_flags"],
        "ack_hex":   ackpkt["hex_clean"],
    })

df_handshake = pd.DataFrame(handshake_rows)
df_handshake.head()
# Out:
#        flow_id  syn_id syn_type  syn_seq  syn_ack  syn_wss syn_flags  \
# 0  12345-56039       1      SYN        0        0    65535    0x0002
# 1  12345-56040      12      SYN        0        0    65535    0x0002
# 2  12345-56041      23      SYN        0        0    65535    0x0002
# 3  12345-56042      33      SYN        0        0    65535    0x0002
# 4  12345-56043      44      SYN        0        0    65535    0x0002
#
#                                              syn_hex  synack_id synack_type  \
# 0  02000000450000346d364000800600007f0000017f0000...          2     SYN-ACK
# 1  02000000450000346d414000800600007f0000017f0000...         13     SYN-ACK
# 2  02000000450000346d4c4000800600007f0000017f0000...         24     SYN-ACK
# 3  02000000450000286d564000800600007f0000017f0000...         34     SYN-ACK
# 4  02000000450000286d614000800600007f0000017f0000...         45     SYN-ACK
#
#    ...  synack_wss  synack_flags  \
# 0  ...       65535        0x0012
# 1  ...       65535        0x0012
# 2  ...       65535        0x0012
# 3  ...       65535        0x0012
# 4  ...       65535        0x0012
#
#                                           synack_hex ack_id ack_type  ack_seq  \
# 0  02000000450000346d374000800600007f0000017f0000...      3      ACK        1
# 1  02000000450000346d424000800600007f0000017f0000...     14      ACK        1
# 2  02000000450000346d4d4000800600007f0000017f0000...     25      ACK        1
# 3  02000000450000346d574000800600007f0000017f0000...     35      ACK        1
# 4  02000000450000346d624000800600007f0000017f0000...     46      ACK        1
#
#   ack_ack  ack_wss  ack_flags  \
# 0       1      255     0x0010
# 1       1      255     0x0010
# 2       1      255     0x0010
# 3       1      255     0x0010
# 4       1      255     0x0010
#
#                                              ack_hex
# 0  02000000450000286d384000800600007f0000017f0000...
# 1  02000000450000286d434000800600007f0000017f0000...
# 2  02000000450000286d4e4000800600007f0000017f0000...
# 3  02000000450000346d584000800600007f0000017f0000...
# 4  02000000450000346d634000800600007f0000017f0000...
#
# [5 rows x 22 columns]

# %%
df_handshake.to_csv("/content/tcp_handshakes_ground_truth.csv", index=False)
print("Saved tcp_handshakes_ground_truth.csv")
# Out:
# Saved tcp_handshakes_ground_truth.csv

# %%
import pandas as pd
import random

df_handshake = pd.read_csv("/content/tcp_handshakes_ground_truth.csv")
df_handshake.head()
# Out:
#        flow_id  syn_id syn_type  syn_seq  syn_ack  syn_wss syn_flags  \
# 0  12345-56039       1      SYN        0        0    65535    0x0002
# 1  12345-56040      12      SYN        0        0    65535    0x0002
# 2  12345-56041      23      SYN        0        0    65535    0x0002
# 3  12345-56042      33      SYN        0        0    65535    0x0002
# 4  12345-56043      44      SYN        0        0    65535    0x0002
#
#                                              syn_hex  synack_id synack_type  \
# 0  02000000450000346d364000800600007f0000017f0000...          2     SYN-ACK
# 1  02000000450000346d414000800600007f0000017f0000...         13     SYN-ACK
# 2  02000000450000346d4c4000800600007f0000017f0000...         24     SYN-ACK
# 3  02000000450000286d564000800600007f0000017f0000...         34     SYN-ACK
# 4  02000000450000286d614000800600007f0000017f0000...         45     SYN-ACK
#
#    ...  synack_wss  synack_flags  \
# 0  ...       65535        0x0012
# 1  ...       65535        0x0012
# 2  ...       65535        0x0012
# 3  ...       65535        0x0012
# 4  ...       65535        0x0012
#
#                                           synack_hex ack_id ack_type  ack_seq  \
# 0  02000000450000346d374000800600007f0000017f0000...      3      ACK        1
# 1  02000000450000346d424000800600007f0000017f0000...     14      ACK        1
# 2  02000000450000346d4d4000800600007f0000017f0000...     25      ACK        1
# 3  02000000450000346d574000800600007f0000017f0000...     35      ACK        1
# 4  02000000450000346d624000800600007f0000017f0000...     46      ACK        1
#
#   ack_ack  ack_wss  ack_flags  \
# 0       1      255     0x0010
# 1       1      255     0x0010
# 2       1      255     0x0010
# 3       1      255     0x0010
# 4       1      255     0x0010
#
#                                              ack_hex
# 0  02000000450000286d384000800600007f0000017f0000...
# 1  02000000450000286d434000800600007f0000017f0000...
# 2  02000000450000286d4e4000800600007f0000017f0000...
# 3  02000000450000346d584000800600007f0000017f0000...
# 4  02000000450000346d634000800600007f0000017f0000...
#
# [5 rows x 22 columns]

# %% [markdown]
# # **2. Fuzzing**

# %% [markdown]
# **Initial Seed**

# %%
cols_for_seed = [
    "flow_id",

    "syn_hex",
    "syn_type",
    "syn_seq",
    "syn_ack",
    "syn_wss",
    "syn_flags",

    "synack_hex",
    "synack_type",
    "synack_seq",
    "synack_ack",
    "synack_wss",
    "synack_flags",

    "ack_hex",      # ground truth output for LLM
    "ack_type",
    "ack_seq",
    "ack_ack",
    "ack_wss",
    "ack_flags",
]

df_task2 = df_handshake[cols_for_seed].copy()
df_task2.head()
# Out:
#        flow_id                                            syn_hex syn_type  \
# 0  12345-56039  02000000450000346d364000800600007f0000017f0000...      SYN
# 1  12345-56040  02000000450000346d414000800600007f0000017f0000...      SYN
# 2  12345-56041  02000000450000346d4c4000800600007f0000017f0000...      SYN
# 3  12345-56042  02000000450000286d564000800600007f0000017f0000...      SYN
# 4  12345-56043  02000000450000286d614000800600007f0000017f0000...      SYN
#
#    syn_seq  syn_ack  syn_wss syn_flags  \
# 0        0        0    65535    0x0002
# 1        0        0    65535    0x0002
# 2        0        0    65535    0x0002
# 3        0        0    65535    0x0002
# 4        0        0    65535    0x0002
#
#                                           synack_hex synack_type  synack_seq  \
# 0  02000000450000346d374000800600007f0000017f0000...     SYN-ACK           0
# 1  02000000450000346d424000800600007f0000017f0000...     SYN-ACK           0
# 2  02000000450000346d4d4000800600007f0000017f0000...     SYN-ACK           0
# 3  02000000450000346d574000800600007f0000017f0000...     SYN-ACK           0
# 4  02000000450000346d624000800600007f0000017f0000...     SYN-ACK           0
#
#    synack_ack  synack_wss synack_flags  \
# 0           1       65535       0x0012
# 1           1       65535       0x0012
# 2           1       65535       0x0012
# 3           1       65535       0x0012
# 4           1       65535       0x0012
#
#                                              ack_hex ack_type  ack_seq  \
# 0  02000000450000286d384000800600007f0000017f0000...      ACK        1
# 1  02000000450000286d434000800600007f0000017f0000...      ACK        1
# 2  02000000450000286d4e4000800600007f0000017f0000...      ACK        1
# 3  02000000450000346d584000800600007f0000017f0000...      ACK        1
# 4  02000000450000346d634000800600007f0000017f0000...      ACK        1
#
#    ack_ack  ack_wss ack_flags
# 0        1      255    0x0010
# 1        1      255    0x0010
# 2        1      255    0x0010
# 3        1      255    0x0010
# 4        1      255    0x0010

# %%
import pandas as pd
df_gt = pd.read_csv("/content/tcp_handshakes_ground_truth.csv")
print(df_gt.columns.tolist())
# Out:
# ['flow_id', 'syn_id', 'syn_type', 'syn_seq', 'syn_ack', 'syn_wss', 'syn_flags', 'syn_hex', 'synack_id', 'synack_type', 'synack_seq', 'synack_ack', 'synack_wss', 'synack_flags', 'synack_hex', 'ack_id', 'ack_type', 'ack_seq', 'ack_ack', 'ack_wss', 'ack_flags', 'ack_hex']

# %% [markdown]
# **HEX Mutation**

# %%
def mutate_hex(hex_str, num_mutations=2):
    """
    hex_str: string like '0200000045000034...'
    Randomly changes num_mutations hex digits.
    """
    hex_str = str(hex_str)
    hex_list = list(hex_str)

    for _ in range(num_mutations):
        i = random.randrange(len(hex_list))
        hex_list[i] = random.choice("0123456789abcdef")

    return "".join(hex_list)

# %% [markdown]
# **SYN and SYN ACK Mutation**

# %%
import random

def mutate_hex(hex_str, num_flips=2):
    b = bytearray.fromhex(hex_str)
    for _ in range(num_flips):
        i = random.randrange(len(b))
        b[i] ^= 0xFF
    return b.hex()

df_task2 = df_gt.copy()

# mutate ONLY the seeds you feed the LLM (SYN + SYN-ACK)
df_task2["syn_hex_mut"] = df_task2["syn_hex"].apply(lambda x: mutate_hex(x, num_flips=2))
df_task2["synack_hex_mut"] = df_task2["synack_hex"].apply(lambda x: mutate_hex(x, num_flips=2))

# %% [markdown]
# # **3. LLM Prompting (GPT 4.1)**

# %% [markdown]
# **3a. Build prompt using persona + template engineering**

# %%
df2_task2 = df_task2

# %%
import openai
openai.api_key = "sk-............"

# %%
def build_prompt(row):
    return f"""You are analyzing a TCP 3-way handshake on localhost.

Packet 1 (possibly mutated SYN):
  Type: {row['syn_type']}
  Flags: {row['syn_flags']}
  Seq: {row['syn_seq']}
  Ack: {row['syn_ack']}
  Window: {row['syn_wss']}
  Hex: {row['syn_hex_mut']}

Packet 2 (possibly mutated SYN-ACK):
  Type: {row['synack_type']}
  Flags: {row['synack_flags']}
  Seq: {row['synack_seq']}
  Ack: {row['synack_ack']}
  Window: {row['synack_wss']}
  Hex: {row['synack_hex_mut']}

Some bytes may be corrupted due to fuzzing.

Task:
Generate the third packet of this handshake (the final ACK) as a HEX STRING ONLY,
with no spaces and no explanation.
"""

df_task2["prompt"] = df_task2.apply(build_prompt, axis=1)

print("Has prompt?", "prompt" in df_task2.columns)
df_task2[["flow_id","prompt"]].head(1)
# Out:
# Has prompt? True
#        flow_id                                             prompt
# 0  12345-56039  You are analyzing a TCP 3-way handshake on loc...

# %%
print(df_task2.columns.tolist())
# Out:
# ['flow_id', 'syn_id', 'syn_type', 'syn_seq', 'syn_ack', 'syn_wss', 'syn_flags', 'syn_hex', 'synack_id', 'synack_type', 'synack_seq', 'synack_ack', 'synack_wss', 'synack_flags', 'synack_hex', 'ack_id', 'ack_type', 'ack_seq', 'ack_ack', 'ack_wss', 'ack_flags', 'ack_hex', 'syn_hex_mut', 'synack_hex_mut', 'prompt']

# %% [markdown]
# **3b. Run prompt 20 times**

# %%
from tqdm import trange

runs = []

for run_id in trange(20):
    for _, row in df_task2.iterrows():
        response = openai.ChatCompletion.create(
            model="gpt-4.1",
            messages=[
                {"role": "system", "content": "You are a TCP packet generator."},
                {"role": "user", "content": row["prompt"]}
            ]
        )

        llm_hex = response["choices"][0]["message"]["content"].strip()

        runs.append({
            "run_id": run_id,
            "flow_id": row["flow_id"],
            "ack_groundtruth": row["ack_hex"],
            "ack_llm": llm_hex
        })

df_runs = pd.DataFrame(runs)
df_runs.head()
# Out:
# 100%|██████████| 20/20 [07:10<00:00, 21.51s/it]
#    run_id      flow_id                                    ack_groundtruth  \
# 0       0  12345-56039  02000000450000286d384000800600007f0000017f0000...
# 1       0  12345-56040  02000000450000286d434000800600007f0000017f0000...
# 2       0  12345-56041  02000000450000286d4e4000800600007f0000017f0000...
# 3       0  12345-56042  02000000450000346d584000800600007f0000017f0000...
# 4       0  12345-56043  02000000450000346d634000800600007f0000017f0000...
#
#                                              ack_llm
# 0  02000000450000346d384100800600007f0000017f0000...
# 1  02000000450000286d4340008006ffff7f0000017f0000...
# 2  02000000450000346d4e4000800600007f0000017f0000...
# 3  02000000450000286d58400080060000800000017f0000...
# 4  02000000450000286d614000801100007f0000017f0000...

# %%
df_runs.to_csv("/content/tcp_baseline_gpt4.1_20.csv", index=False)
print("Saved tcp_baseline_gpt4.1_task2_20.csv")
# Out:
# Saved tcp_baseline_gpt4.1_task2_20.csv

# %% [markdown]
# **3c. Build prompt using persona + template engineering + One shot + Chain of Thought**

# %%
print(df_task2.columns.tolist())
# Out:
# ['flow_id', 'syn_id', 'syn_type', 'syn_seq', 'syn_ack', 'syn_wss', 'syn_flags', 'syn_hex', 'synack_id', 'synack_type', 'synack_seq', 'synack_ack', 'synack_wss', 'synack_flags', 'synack_hex', 'ack_id', 'ack_type', 'ack_seq', 'ack_ack', 'ack_wss', 'ack_flags', 'ack_hex', 'syn_hex_mut', 'synack_hex_mut', 'prompt']

# %%
import pandas as pd

df_gt = pd.read_csv("/content/tcp_handshakes_ground_truth.csv")

# Use the FIRST real handshake as one-shot example
ex = df_gt.iloc[0]

ONE_SHOT = f"""
ONE-SHOT EXAMPLE (REAL HANDSHAKE)

Packet 1 (SYN):
Hex: {ex['syn_hex']}

Packet 2 (SYN-ACK):
Hex: {ex['synack_hex']}

Correct Packet 3 (ACK):
Hex: {ex['ack_hex']}
""".strip()

print(ONE_SHOT[:500])
# Out:
# ONE-SHOT EXAMPLE (REAL HANDSHAKE)
#
# Packet 1 (SYN):
# Hex: 02000000450000346d364000800600007f0000017f000001ca3b303938253e79000000008002ffff05d700000204ffd70103030801010402
#
# Packet 2 (SYN-ACK):
# Hex: 02000000450000346d374000800600007f0000017f0000013039ca3b57dc1f220938253e7a8012ffff8ec700000204ffd70103030801010402
#
# Correct Packet 3 (ACK):
# Hex: 02000000450000286d384000800600007f0000017f000001ca3b303938253e7a57dc1f23501000ffc8bf0000

# %%
def build_prompt(row):
    return f"""You are analyzing TCP 3-way handshakes on localhost.

{ONE_SHOT}

NOW SOLVE THIS CASE:

Packet 1 (possibly mutated SYN):
Hex: {row['syn_hex_mut']}

Packet 2 (possibly mutated SYN-ACK):
Hex: {row['synack_hex_mut']}

Instructions:
- Think step-by-step silently to ensure correctness.
- Output ONLY the final ACK packet as a HEX STRING.
- No spaces, no explanation, no extra text.
"""

# %%
df_task2["prompt"] = df_task2.apply(build_prompt, axis=1)

# %%
print(df_task2["prompt"].iloc[0][:400])
# Out:
# You are analyzing TCP 3-way handshakes on localhost.
#
# ONE-SHOT EXAMPLE (REAL HANDSHAKE)
#
# Packet 1 (SYN):
# Hex: 02000000450000346d364000800600007f0000017f000001ca3b303938253e79000000008002ffff05d700000204ffd70103030801010402
#
# Packet 2 (SYN-ACK):
# Hex: 02000000450000346d374000800600007f0000017f0000013039ca3b57dc1f220938253e7a8012ffff8ec700000204ffd70103030801010402
#
# Correct Packet 3 (ACK):
# Hex: 020000

# %% [markdown]
# **3d. Run prompt 20 times**

# %%
import openai
import os
from tqdm import trange

openai.api_key = "sk-..............."

ROWS = []

for run_id in trange(20, desc="20 LLM runs"):
    for _, row in df_task2.iterrows():

        response = openai.ChatCompletion.create(
            model="gpt-4.1",
            temperature=0.2,
            messages=[
                {"role": "system", "content": "You generate valid TCP packets."},
                {"role": "user", "content": row["prompt"]}
            ]
        )

        ack_llm = response["choices"][0]["message"]["content"].strip()

        ROWS.append({
            "run_id": run_id,
            "flow_id": row["flow_id"],
            "syn_hex_mut": row["syn_hex_mut"],
            "synack_hex_mut": row["synack_hex_mut"],
            "ack_hex_gt": row["ack_hex"],
            "ack_hex_llm": ack_llm
        })
# Out:
# 20 LLM runs: 100%|██████████| 20/20 [06:42<00:00, 20.12s/it]

# %%
df_20 = pd.DataFrame(ROWS)
df_20.to_csv("tcp_oneshot_gpt4.1_20.csv", index=False)

print("Saved tcp_oneshot_gpt4.1_20.csv")
df_20.head()
# Out:
# Saved tcp_oneshot_gpt4.1_20.csv
#    run_id      flow_id                                        syn_hex_mut  \
# 0       0  12345-56039  02000000450000346d36bf00800600007f0000017f0000...
# 1       0  12345-56040  02000000450000346d41400080f900007f0000017f0000...
# 2       0  12345-56041  02000000450000346d4c4000800600007f00ff017f0000...
# 3       0  12345-56042  02000000450000286d56400080060000800000017f0000...
# 4       0  12345-56043  02000000ba0000286d614000800600007f0000017fff00...
#
#                                       synack_hex_mut  \
# 0  02000000450000346d374000800600007f0000017fff00...
# 1  02000000450000346d4240008006ffff7f0000017f0000...
# 2  02000000450000346d4d400080f900007f0000017f0000...
# 3  02000000450000346d574000800600007f0000017f0000...
# 4  02000000450000346d62400080f900007f0000017f0000...
#
#                                           ack_hex_gt  \
# 0  02000000450000286d384000800600007f0000017f0000...
# 1  02000000450000286d434000800600007f0000017f0000...
# 2  02000000450000286d4e4000800600007f0000017f0000...
# 3  02000000450000346d584000800600007f0000017f0000...
# 4  02000000450000346d634000800600007f0000017f0000...
#
#                                          ack_hex_llm
# 0  02000000450000286d384000800600007f0000017f0000...
# 1  02000000450000286d434000800600007f0000017f0000...
# 2  02000000450000286d4e4000800600007f00ff017f0000...
# 3  02000000450000286d584000800600007f0000017f0000...
# 4  02000000450000286d634000800600007f0000017fff00...

# %% [markdown]
# # **3. LLM Prompting (GPT 3.5)**

# %% [markdown]
# **3a. Build prompt using persona + template engineering**

# %%
import openai
openai.api_key = "sk-.............."

# %%
def build_prompt(row):
    return f"""You are analyzing a TCP 3-way handshake on localhost.

Packet 1 (possibly mutated SYN):
  Type: {row['syn_type']}
  Flags: {row['syn_flags']}
  Seq: {row['syn_seq']}
  Ack: {row['syn_ack']}
  Window: {row['syn_wss']}
  Hex: {row['syn_hex_mut']}

Packet 2 (possibly mutated SYN-ACK):
  Type: {row['synack_type']}
  Flags: {row['synack_flags']}
  Seq: {row['synack_seq']}
  Ack: {row['synack_ack']}
  Window: {row['synack_wss']}
  Hex: {row['synack_hex_mut']}

Some bytes may be corrupted due to fuzzing.

Task:
Generate the third packet of this handshake (the final ACK) as a HEX STRING ONLY,
with no spaces and no explanation.
"""

df_task2["prompt"] = df_task2.apply(build_prompt, axis=1)

print("Has prompt?", "prompt" in df_task2.columns)
df_task2[["flow_id","prompt"]].head(1)
# Out:
# Has prompt? True
#        flow_id                                             prompt
# 0  12345-56039  You are analyzing a TCP 3-way handshake on loc...

# %% [markdown]
# **3b. Run prompt 20 times**

# %%
from tqdm import trange

runs = []

for run_id in trange(20):
    for _, row in df_task2.iterrows():
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are a TCP packet generator."},
                {"role": "user", "content": row["prompt"]}
            ]
        )

        llm_hex = response["choices"][0]["message"]["content"].strip()

        runs.append({
            "run_id": run_id,
            "flow_id": row["flow_id"],
            "ack_groundtruth": row["ack_hex"],
            "ack_llm": llm_hex
        })

df_runs = pd.DataFrame(runs)
df_runs.head()
# Out:
# 100%|██████████| 20/20 [04:14<00:00, 12.72s/it]
#    run_id      flow_id                                    ack_groundtruth  \
# 0       0  12345-56039  02000000450000286d384000800600007f0000017f0000...
# 1       0  12345-56040  02000000450000286d434000800600007f0000017f0000...
# 2       0  12345-56041  02000000450000286d4e4000800600007f0000017f0000...
# 3       0  12345-56042  02000000450000346d584000800600007f0000017f0000...
# 4       0  12345-56043  02000000450000346d634000800600007f0000017f0000...
#
#                                              ack_llm
# 0  02000000450000346d376100800600007f0000017f0000...
# 1  02000000450000346d4340008006ffff7f0000017f0000...
# 2  0201405a00000102cb6c5a24bbfe00516d4c19cbff0050...
# 3  0602125045000028000001060000007f0000017f000001...
# 4  020000006d9cbea8ca3f30390200000050028010ffcfa6...

# %%
df_runs.to_csv("/content/tcp_baseline_gpt3.5_20.csv", index=False)
print("Saved tcp_baseline_gpt3.5_20.csv")
# Out:
# Saved tcp_baseline_gpt3.5_20.csv

# %% [markdown]
# **3c. Build prompt using persona + template engineering + One shot + Chain of Thought**

# %%
import pandas as pd

df_gt = pd.read_csv("/content/tcp_handshakes_ground_truth.csv")

# Use the FIRST real handshake as one-shot example
ex = df_gt.iloc[0]

ONE_SHOT = f"""
ONE-SHOT EXAMPLE (REAL HANDSHAKE)

Packet 1 (SYN):
Hex: {ex['syn_hex']}

Packet 2 (SYN-ACK):
Hex: {ex['synack_hex']}

Correct Packet 3 (ACK):
Hex: {ex['ack_hex']}
""".strip()

print(ONE_SHOT[:500])
# Out:
# ONE-SHOT EXAMPLE (REAL HANDSHAKE)
#
# Packet 1 (SYN):
# Hex: 02000000450000346d364000800600007f0000017f000001ca3b303938253e79000000008002ffff05d700000204ffd70103030801010402
#
# Packet 2 (SYN-ACK):
# Hex: 02000000450000346d374000800600007f0000017f0000013039ca3b57dc1f220938253e7a8012ffff8ec700000204ffd70103030801010402
#
# Correct Packet 3 (ACK):
# Hex: 02000000450000286d384000800600007f0000017f000001ca3b303938253e7a57dc1f23501000ffc8bf0000

# %%
def build_prompt(row):
    return f"""You are analyzing TCP 3-way handshakes on localhost.

{ONE_SHOT}

NOW SOLVE THIS CASE:

Packet 1 (possibly mutated SYN):
Hex: {row['syn_hex_mut']}

Packet 2 (possibly mutated SYN-ACK):
Hex: {row['synack_hex_mut']}

Instructions:
- Think step-by-step silently to ensure correctness.
- Output ONLY the final ACK packet as a HEX STRING.
- No spaces, no explanation, no extra text.
"""

# %%
df_task2["prompt"] = df_task2.apply(build_prompt, axis=1)

# %% [markdown]
# **3b. Run prompt 20 times**

# %%
from tqdm import trange

runs = []

for run_id in trange(20):
    for _, row in df_task2.iterrows():
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are a TCP packet generator."},
                {"role": "user", "content": row["prompt"]}
            ]
        )

        llm_hex = response["choices"][0]["message"]["content"].strip()

        runs.append({
            "run_id": run_id,
            "flow_id": row["flow_id"],
            "ack_groundtruth": row["ack_hex"],
            "ack_llm": llm_hex
        })

df_runs = pd.DataFrame(runs)
df_runs.head()
# Out:
# 100%|██████████| 20/20 [04:22<00:00, 13.14s/it]
#    run_id      flow_id                                    ack_groundtruth  \
# 0       0  12345-56039  02000000450000286d384000800600007f0000017f0000...
# 1       0  12345-56040  02000000450000286d434000800600007f0000017f0000...
# 2       0  12345-56041  02000000450000286d4e4000800600007f0000017f0000...
# 3       0  12345-56042  02000000450000346d584000800600007f0000017f0000...
# 4       0  12345-56043  02000000450000346d634000800600007f0000017f0000...
#
#                                              ack_llm
# 0  02000000450000286d384000800600007f0000017f0000...
# 1  02000000450000346d414000800600007f0000017f0000...
# 2  02000000450000286d4e4000800600007f00ff017f0000...
# 3  02000000450000286d384000800600007f0000017f0000...
# 4  02000000450000286d634000800600007f0000017f0000...

# %%
df_runs.to_csv("/content/tcp_oneshot_gpt3.5_20.csv", index=False)
print("Saved tcp_oneshot_gpt3.5_20.csv")
# Out:
# Saved tcp_oneshot_gpt3.5_20.csv

# %% [markdown]
# # **4a. Evaluation (GPT 4.1)**

# %% [markdown]
# **4a. For Baseline (persona + template prompting)**

# %%
import pandas as pd

df = pd.read_csv("/content/tcp_baseline_gpt4.1_20.csv")
print(df.columns)
df.head()
# Out:
# Index(['run_id', 'flow_id', 'ack_groundtruth', 'ack_llm'], dtype='object')
#    run_id      flow_id                                    ack_groundtruth  \
# 0       0  12345-56039  02000000450000286d384000800600007f0000017f0000...
# 1       0  12345-56040  02000000450000286d434000800600007f0000017f0000...
# 2       0  12345-56041  02000000450000286d4e4000800600007f0000017f0000...
# 3       0  12345-56042  02000000450000346d584000800600007f0000017f0000...
# 4       0  12345-56043  02000000450000346d634000800600007f0000017f0000...
#
#                                              ack_llm
# 0  02000000450000346d384100800600007f0000017f0000...
# 1  02000000450000286d4340008006ffff7f0000017f0000...
# 2  02000000450000346d4e4000800600007f0000017f0000...
# 3  02000000450000286d58400080060000800000017f0000...
# 4  02000000450000286d614000801100007f0000017f0000...

# %% [markdown]
# **Classify PAcket type**

# %%
def classify_tcp_type(hex_str):
    try:
        b = bytes.fromhex(hex_str)

        # Find TCP flags byte (robust enough for your captures)
        flags = b[-7]

        syn = flags & 0x02
        ack = flags & 0x10
        fin = flags & 0x01
        rst = flags & 0x04

        if syn and ack:
            return "SYN-ACK"
        if syn:
            return "SYN"
        if ack and not fin and not rst:
            return "ACK"
        if fin:
            return "FIN"
        if rst:
            return "RST"
        return "OTHER"
    except Exception:
        return "INVALID"

# %%
# IMPORTANT: adjust column name if needed
df["pkt_type"] = df["ack_llm"].apply(classify_tcp_type)

# %%
print(df[["ack_llm", "pkt_type"]].head())
# Out:
#                                              ack_llm pkt_type
# 0  02000000450000346d384100800600007f0000017f0000...      SYN
# 1  02000000450000286d4340008006ffff7f0000017f0000...    OTHER
# 2  02000000450000346d4e4000800600007f0000017f0000...      ACK
# 3  02000000450000286d58400080060000800000017f0000...    OTHER
# 4  02000000450000286d614000801100007f0000017f0000...      ACK

# %%
df["is_valid"] = df["pkt_type"].isin(
    ["ACK", "SYN", "SYN-ACK", "FIN", "RST"]
)

df["is_ack"] = df["pkt_type"] == "ACK"

df["is_hallucination"] = ~df["is_valid"]

# %%
grouped = df.groupby("flow_id")

# %%
missing_rate = grouped["is_ack"].apply(lambda x: 1 - x.mean()).mean()

# %%
hallucination_rate = grouped["is_hallucination"].mean().mean()

# %%
valid_unique_types = (
    df[df["is_valid"]]
    .groupby("flow_id")["pkt_type"]
    .nunique()
    .mean()
)

# %%
relative_position_score = grouped["is_ack"].mean().mean()

# %%
results = pd.DataFrame([{
    "Model": "gpt-4.1",
    "Prompting": "Baseline",
    "Average Packet Types after Enrichment": 1.0,
    "Valid Unique Packet Types": valid_unique_types,
    "Missing Packet Type Rate": missing_rate,
    "Hallucination Rate": hallucination_rate,
    "Average Relative Position Score": relative_position_score
}])
results
# Out:
#      Model Prompting  Average Packet Types after Enrichment  \
# 0  gpt-4.1  Baseline                                    1.0
#
#    Valid Unique Packet Types  Missing Packet Type Rate  Hallucination Rate  \
# 0                       1.95                    0.4725                0.37
#
#    Average Relative Position Score
# 0                           0.5275

# %% [markdown]
# **4b. For  baseline + One shot + CoT**

# %%
import pandas as pd

df = pd.read_csv("/content/tcp_oneshot_gpt4.1_20.csv")
print(df.columns)
df.head()
# Out:
# Index(['run_id', 'flow_id', 'syn_hex_mut', 'synack_hex_mut', 'ack_hex_gt',
#        'ack_hex_llm'],
#       dtype='object')
#    run_id      flow_id                                        syn_hex_mut  \
# 0       0  12345-56039  02000000450000346d36bf00800600007f0000017f0000...
# 1       0  12345-56040  02000000450000346d41400080f900007f0000017f0000...
# 2       0  12345-56041  02000000450000346d4c4000800600007f00ff017f0000...
# 3       0  12345-56042  02000000450000286d56400080060000800000017f0000...
# 4       0  12345-56043  02000000ba0000286d614000800600007f0000017fff00...
#
#                                       synack_hex_mut  \
# 0  02000000450000346d374000800600007f0000017fff00...
# 1  02000000450000346d4240008006ffff7f0000017f0000...
# 2  02000000450000346d4d400080f900007f0000017f0000...
# 3  02000000450000346d574000800600007f0000017f0000...
# 4  02000000450000346d62400080f900007f0000017f0000...
#
#                                           ack_hex_gt  \
# 0  02000000450000286d384000800600007f0000017f0000...
# 1  02000000450000286d434000800600007f0000017f0000...
# 2  02000000450000286d4e4000800600007f0000017f0000...
# 3  02000000450000346d584000800600007f0000017f0000...
# 4  02000000450000346d634000800600007f0000017f0000...
#
#                                          ack_hex_llm
# 0  02000000450000286d384000800600007f0000017f0000...
# 1  02000000450000286d434000800600007f0000017f0000...
# 2  02000000450000286d4e4000800600007f00ff017f0000...
# 3  02000000450000286d584000800600007f0000017f0000...
# 4  02000000450000286d634000800600007f0000017fff00...

# %%
def classify_tcp_type(hex_str):
    try:
        b = bytes.fromhex(hex_str)

        # Find TCP flags byte (robust enough for your captures)
        flags = b[-7]

        syn = flags & 0x02
        ack = flags & 0x10
        fin = flags & 0x01
        rst = flags & 0x04

        if syn and ack:
            return "SYN-ACK"
        if syn:
            return "SYN"
        if ack and not fin and not rst:
            return "ACK"
        if fin:
            return "FIN"
        if rst:
            return "RST"
        return "OTHER"
    except Exception:
        return "INVALID"

# %%
# IMPORTANT: adjust column name if needed
df["pkt_type"] = df["ack_hex_llm"].apply(classify_tcp_type)

# %%
print(df[["ack_hex_llm", "pkt_type"]].head())
# Out:
#                                          ack_hex_llm pkt_type
# 0  02000000450000286d384000800600007f0000017f0000...      ACK
# 1  02000000450000286d434000800600007f0000017f0000...      ACK
# 2  02000000450000286d4e4000800600007f00ff017f0000...      FIN
# 3  02000000450000286d584000800600007f0000017f0000...      ACK
# 4  02000000450000286d634000800600007f0000017fff00...      ACK

# %%
df["is_valid"] = df["pkt_type"].isin(
    ["ACK", "SYN", "SYN-ACK", "FIN", "RST"]
)

df["is_ack"] = df["pkt_type"] == "ACK"

df["is_hallucination"] = ~df["is_valid"]

# %%
grouped = df.groupby("flow_id")

# %%
missing_rate = grouped["is_ack"].apply(lambda x: 1 - x.mean()).mean()

# %%
hallucination_rate = grouped["is_hallucination"].mean().mean()

# %%
valid_unique_types = (
    df[df["is_valid"]]
    .groupby("flow_id")["pkt_type"]
    .nunique()
    .mean()
)

# %%
relative_position_score = grouped["is_ack"].mean().mean()

# %%
results2 = pd.DataFrame([{
    "Model": "gpt-4.1",
    "Prompting": "one-shot + CoT",
    "Average Packet Types after Enrichment": 1.0,
    "Valid Unique Packet Types": valid_unique_types,
    "Missing Packet Type Rate": missing_rate,
    "Hallucination Rate": hallucination_rate,
    "Average Relative Position Score": relative_position_score
}])
results2
# Out:
#      Model       Prompting  Average Packet Types after Enrichment  \
# 0  gpt-4.1  one-shot + CoT                                    1.0
#
#    Valid Unique Packet Types  Missing Packet Type Rate  Hallucination Rate  \
# 0                   1.210526                     0.435              0.3875
#
#    Average Relative Position Score
# 0                            0.565

# %%
# Stack rows
df_merged = pd.concat([results, results2], ignore_index=True)

df_merged
# Out:
#      Model       Prompting  Average Packet Types after Enrichment  \
# 0  gpt-4.1        Baseline                                    1.0
# 1  gpt-4.1  one-shot + CoT                                    1.0
#
#    Valid Unique Packet Types  Missing Packet Type Rate  Hallucination Rate  \
# 0                   1.950000                    0.4725              0.3700
# 1                   1.210526                    0.4350              0.3875
#
#    Average Relative Position Score
# 0                           0.5275
# 1                           0.5650

# %% [markdown]
# # **4a. Evaluation (GPT 3.5)**

# %% [markdown]
# **4a. For Baseline (persona + template prompting)**

# %%
import pandas as pd

df = pd.read_csv("/content/tcp_baseline_gpt3.5_20.csv")
print(df.columns)
df.head()
# Out:
# Index(['run_id', 'flow_id', 'ack_groundtruth', 'ack_llm'], dtype='object')
#    run_id      flow_id                                    ack_groundtruth  \
# 0       0  12345-56039  02000000450000286d384000800600007f0000017f0000...
# 1       0  12345-56040  02000000450000286d434000800600007f0000017f0000...
# 2       0  12345-56041  02000000450000286d4e4000800600007f0000017f0000...
# 3       0  12345-56042  02000000450000346d584000800600007f0000017f0000...
# 4       0  12345-56043  02000000450000346d634000800600007f0000017f0000...
#
#                                              ack_llm
# 0  02000000450000346d376100800600007f0000017f0000...
# 1  02000000450000346d4340008006ffff7f0000017f0000...
# 2  0201405a00000102cb6c5a24bbfe00516d4c19cbff0050...
# 3  0602125045000028000001060000007f0000017f000001...
# 4  020000006d9cbea8ca3f30390200000050028010ffcfa6...

# %%
def classify_tcp_type(hex_str):
    try:
        b = bytes.fromhex(hex_str)

        # Find TCP flags byte (robust enough for your captures)
        flags = b[-7]

        syn = flags & 0x02
        ack = flags & 0x10
        fin = flags & 0x01
        rst = flags & 0x04

        if syn and ack:
            return "SYN-ACK"
        if syn:
            return "SYN"
        if ack and not fin and not rst:
            return "ACK"
        if fin:
            return "FIN"
        if rst:
            return "RST"
        return "OTHER"
    except Exception:
        return "INVALID"

# %%
# IMPORTANT: adjust column name if needed
df["pkt_type"] = df["ack_llm"].apply(classify_tcp_type)

# %%
print(df[["ack_llm", "pkt_type"]].head())
# Out:
#                                              ack_llm pkt_type
# 0  02000000450000346d376100800600007f0000017f0000...      RST
# 1  02000000450000346d4340008006ffff7f0000017f0000...  INVALID
# 2  0201405a00000102cb6c5a24bbfe00516d4c19cbff0050...  INVALID
# 3  0602125045000028000001060000007f0000017f000001...  INVALID
# 4  020000006d9cbea8ca3f30390200000050028010ffcfa6...  INVALID

# %%
df["is_valid"] = df["pkt_type"].isin(
    ["ACK", "SYN", "SYN-ACK", "FIN", "RST"]
)

df["is_ack"] = df["pkt_type"] == "ACK"

df["is_hallucination"] = ~df["is_valid"]

# %%
grouped = df.groupby("flow_id")

# %%
missing_rate = grouped["is_ack"].apply(lambda x: 1 - x.mean()).mean()

# %%
hallucination_rate = grouped["is_hallucination"].mean().mean()

# %%
valid_unique_types = (
    df[df["is_valid"]]
    .groupby("flow_id")["pkt_type"]
    .nunique()
    .mean()
)

# %%
relative_position_score = grouped["is_ack"].mean().mean()

# %%
results3 = pd.DataFrame([{
    "Model": "gpt-3.5",
    "Prompting": "baseline",
    "Average Packet Types after Enrichment": 1.0,
    "Valid Unique Packet Types": valid_unique_types,
    "Missing Packet Type Rate": missing_rate,
    "Hallucination Rate": hallucination_rate,
    "Average Relative Position Score": relative_position_score
}])
results3
# Out:
#      Model Prompting  Average Packet Types after Enrichment  \
# 0  gpt-3.5  baseline                                    1.0
#
#    Valid Unique Packet Types  Missing Packet Type Rate  Hallucination Rate  \
# 0                        3.7                     0.865              0.5575
#
#    Average Relative Position Score
# 0                            0.135

# %%
# Stack rows
df_merged = pd.concat([df_merged, results3], ignore_index=True)

df_merged
# Out:
#      Model       Prompting  Average Packet Types after Enrichment  \
# 0  gpt-4.1        Baseline                                    1.0
# 1  gpt-4.1  one-shot + CoT                                    1.0
# 2  gpt-3.5        baseline                                    1.0
#
#    Valid Unique Packet Types  Missing Packet Type Rate  Hallucination Rate  \
# 0                   1.950000                    0.4725              0.3700
# 1                   1.210526                    0.4350              0.3875
# 2                   3.700000                    0.8650              0.5575
#
#    Average Relative Position Score
# 0                           0.5275
# 1                           0.5650
# 2                           0.1350

# %% [markdown]
# **4b. For  baseline + One shot + CoT**

# %%
import pandas as pd

df = pd.read_csv("/content/tcp_oneshot_gpt3.5_20.csv")
print(df.columns)
df.head()
# Out:
# Index(['run_id', 'flow_id', 'ack_groundtruth', 'ack_llm'], dtype='object')
#    run_id      flow_id                                    ack_groundtruth  \
# 0       0  12345-56039  02000000450000286d384000800600007f0000017f0000...
# 1       0  12345-56040  02000000450000286d434000800600007f0000017f0000...
# 2       0  12345-56041  02000000450000286d4e4000800600007f0000017f0000...
# 3       0  12345-56042  02000000450000346d584000800600007f0000017f0000...
# 4       0  12345-56043  02000000450000346d634000800600007f0000017f0000...
#
#                                              ack_llm
# 0  02000000450000286d384000800600007f0000017f0000...
# 1  02000000450000346d414000800600007f0000017f0000...
# 2  02000000450000286d4e4000800600007f00ff017f0000...
# 3  02000000450000286d384000800600007f0000017f0000...
# 4  02000000450000286d634000800600007f0000017f0000...

# %%
def classify_tcp_type(hex_str):
    try:
        b = bytes.fromhex(hex_str)

        # Find TCP flags byte (robust enough for your captures)
        flags = b[-7]

        syn = flags & 0x02
        ack = flags & 0x10
        fin = flags & 0x01
        rst = flags & 0x04

        if syn and ack:
            return "SYN-ACK"
        if syn:
            return "SYN"
        if ack and not fin and not rst:
            return "ACK"
        if fin:
            return "FIN"
        if rst:
            return "RST"
        return "OTHER"
    except Exception:
        return "INVALID"

# %%
# IMPORTANT: adjust column name if needed
df["pkt_type"] = df["ack_llm"].apply(classify_tcp_type)

# %%
print(df[["ack_llm", "pkt_type"]].head())
# Out:
#                                              ack_llm pkt_type
# 0  02000000450000286d384000800600007f0000017f0000...      FIN
# 1  02000000450000346d414000800600007f0000017f0000...  INVALID
# 2  02000000450000286d4e4000800600007f00ff017f0000...  INVALID
# 3  02000000450000286d384000800600007f0000017f0000...    OTHER
# 4  02000000450000286d634000800600007f0000017f0000...  INVALID

# %%
df["is_valid"] = df["pkt_type"].isin(
    ["ACK", "SYN", "SYN-ACK", "FIN", "RST"]
)

df["is_ack"] = df["pkt_type"] == "ACK"

df["is_hallucination"] = ~df["is_valid"]

# %%
grouped = df.groupby("flow_id")

# %%
missing_rate = grouped["is_ack"].apply(lambda x: 1 - x.mean()).mean()

# %%
hallucination_rate = grouped["is_hallucination"].mean().mean()

# %%
valid_unique_types = (
    df[df["is_valid"]]
    .groupby("flow_id")["pkt_type"]
    .nunique()
    .mean()
)

# %%
relative_position_score = grouped["is_ack"].mean().mean()

# %%
results4 = pd.DataFrame([{
    "Model": "gpt-3.5",
    "Prompting": "one-shot+CoT",
    "Average Packet Types after Enrichment": 1.0,
    "Valid Unique Packet Types": valid_unique_types,
    "Missing Packet Type Rate": missing_rate,
    "Hallucination Rate": hallucination_rate,
    "Average Relative Position Score": relative_position_score
}])
results4
# Out:
#      Model     Prompting  Average Packet Types after Enrichment  \
# 0  gpt-3.5  one-shot+CoT                                    1.0
#
#    Valid Unique Packet Types  Missing Packet Type Rate  Hallucination Rate  \
# 0                        2.5                     0.675              0.5475
#
#    Average Relative Position Score
# 0                            0.325

# %%
# Stack rows
df_merged = pd.concat([df_merged, results4], ignore_index=True)

df_merged
# Out:
#      Model       Prompting  Average Packet Types after Enrichment  \
# 0  gpt-4.1        Baseline                                    1.0
# 1  gpt-4.1  one-shot + CoT                                    1.0
# 2  gpt-3.5        baseline                                    1.0
# 3  gpt-3.5    one-shot+CoT                                    1.0
#
#    Valid Unique Packet Types  Missing Packet Type Rate  Hallucination Rate  \
# 0                   1.950000                    0.4725              0.3700
# 1                   1.210526                    0.4350              0.3875
# 2                   3.700000                    0.8650              0.5575
# 3                   2.500000                    0.6750              0.5475
#
#    Average Relative Position Score
# 0                           0.5275
# 1                           0.5650
# 2                           0.1350
# 3                           0.3250

# %% [markdown]
# # **Final Output**

# %%
df_merged.to_csv("/content/tcp_task2_results.csv", index=False)
print("Saved tcp_task2_results.csv")
# Out:
# Saved tcp_task2_results.csv
